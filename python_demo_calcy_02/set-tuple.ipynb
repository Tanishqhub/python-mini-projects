# %%
count = 0
for i in dir(set):
    if i[0] == "_":
        continue
    else:
        count += 1
        print(count,i)
    # print(type(i))
# Out:
# 1 add
# 2 clear
# 3 copy
# 4 difference
# 5 difference_update
# 6 discard
# 7 intersection
# 8 intersection_update
# 9 isdisjoint
# 10 issubset
# 11 issuperset
# 12 pop
# 13 remove
# 14 symmetric_difference
# 15 symmetric_difference_update
# 16 union
# 17 update

# %%
count = 0
for i in dir(tuple):
    if i[0] == "_":
        continue
    else:
        count += 1
        print(count,i)
    # print(type(i))
# Out:
# 1 count
# 2 index

# %% [markdown]
# ## CH-1 tuple

# %%
# literal

# %%
my_tuple = tuple()

# %%
my_tuple = (1,2,3,4)

# %%
my_tuple[0]
# Out:
# 1

# %%
my_tuple[-1]
# Out:
# 4

# %%
my_tuple[0] = 1 # immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 my_tuple[0] = 1 # immutable
#
# TypeError: 'tuple' object does not support item assignment

# %%
my_tuple.index(3) # return the idex position of the given item
# Out:
# 2

# %%
my_tuple.count(2) # counts the occurence of the given item
# Out:
# 1

# %%
for caren in my_tuple:
    print(caren)
# Out:
# 1
# 2
# 3
# 4
