# %% [markdown]
# ## Elif statements

# %% [markdown]
# #### > additional if sentence

# %%
marks = int(input("Enter your marks"))

if marks > 30:
    print('pass')
elif marks < 12:
    print("Bring your parents")
else:
    print("Quit your education")
# Out:
# Enter your marks 2
# Bring your parents

# %% [markdown]
# ### List

# %% [markdown]
# #### CH-1 List literal

# %%
my_list = list()

# %%
set()
# Out:
# set()

# %%
tuple()
# Out:
# ()

# %%
dict()
# Out:
# {}

# %%
list = [1,3,4]

# %%
del list

# %%
my_list = [1,2,3,4]

# %%
my_list
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# #### CH-2 Indexing

# %%
my_list[0]
# Out:
# 1

# %%
my_list[:-5:-1]
# Out:
# [4, 3, 2, 1]

# %%
my_list[-1]
# Out:
# 4

# %%
my_list
# Out:
# [1, 2, 3, 5]

# %%
my_list[3] = 5

# %% [markdown]
# #### CH-3 Concatenation

# %%
# using '+' we can concatenate two lists

# %%
my_list[3] = 4

# %%
my_list = my_list + [5]

# %%
my_list + 6 # concatenate list with int
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 my_list + 6 # concatenate list with int
#
# TypeError: can only concatenate list (not "int") to list

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
1 + 1
# Out:
# 2

# %%
"1" + "1"
# Out:
# '11'

# %%
[1] + [1]
# Out:
# [1, 1]

# %%
1 + 1.3 + True
# Out:
# 3.3

# %% [markdown]
# #### CH-4 Operations : all methods + del + dir + print(end)

# %%
# 1. append

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
count = 0
for i in dir(list):
    if i[0] == "_":
        continue
    else:
        count += 1
        print(count,i)
    # print(type(i))
# Out:
# 1 append
# 2 clear
# 3 copy
# 4 count
# 5 extend
# 6 index
# 7 insert
# 8 pop
# 9 remove
# 10 reverse
# 11 sort

# %%
my_list = my_list.append(6)

# %%
# 2. clear

# %%
my_list.clear()

# %%
my_list = [1,2,3,4,5]

# %%
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
# 3. copy

# %%
copy_of_list = my_list.copy()

# %%
copy_of_list.clear()

# %%
copy_of_list
# Out:
# []

# %%
# 4. count

# %%
my_list.count(1)
# Out:
# 1

# %%
# 5. extend

# %%
my_list.extend([6,7,8,9,10])

# %%
my_list[3] = 1

# %%
my_list.extend(11) # this wont work

# %%
# 6. index

# %%
my_list.index(1) # returns the index position of a given item
# Out:
# 0

# %%
my_list # index function takes the first item
# Out:
# [1, 2, 3, 1, 5, 6, 7, 8, 9, 10]

# %%
my_list.insert(11,0) # position , item to be appended

# %%
my_list
# Out:
# [1, 2, 3, 1, 5, 6, 7, 8, 9, 10, 0]

# %%
my_list.insert(12, "tanishq") # position , item to be appended

# %%
my_list
# Out:
# [1, 2, 3, 1, 5, 6, 7, 8, 9, 10, 0, 0, 'tanishq']

# %% [markdown]
# ### del

# %%
del my_list[11:13]

# %%
del my_list[10]

# %%
my_list
# Out:
# [1, 2, 3, 1, 5, 6, 7, 8, 9, 10]

# %%
# 7. pop

# %%
my_list.pop()
# Out:
# 10

# %%
my_list
# Out:
# [1, 2, 3, 1, 5, 6, 7, 8, 9]

# %%
# 8. remove

# %%
my_list.remove(1)

# %%
my_list
# Out:
# [2, 3, 1, 5, 6, 7, 8, 9]

# %%
# 10. reverse

# %%
my_list.reverse()

# %%
my_list
# Out:
# [9, 8, 7, 6, 5, 1, 3, 2]

# %%
my_list.reverse()

# %%
my_list
# Out:
# [2, 3, 1, 5, 6, 7, 8, 9]

# %% [markdown]
# #### write a program to remove 1

# %%
for i in my_list:
    # print(1, end=" ")
    if i == 1:
        del i

# %%
my_list
# Out:
# [2, 3, 1, 5, 6, 7, 8, 9]

# %%
# 11. sort

# %%
my_list.sort(reverse = True)

# %%
my_list
# Out:
# [9, 8, 7, 6, 5, 3, 2, 1]

# %%
print("Tanishq" , end=' ')
print("Tanishq")
# Out:
# Tanishq Tanishq

# %%
print("Tanishq" , end=' ')
print("Tanishq")
# Out:
# Tanishq Tanishq

# %% [markdown]
# #### create a list with 5 items

# %%
nums = [1,2,3,4,5]

# %% [markdown]
# #### create a list of 1 lakh items

# %%
len(nums)
# Out:
# 5

# %% [markdown]
# #### CH-5 List comprehension

# %%
nums_1l = [i for i in range(1,100001)]

# %%
len(nums_1l)
# Out:
# 100000

# %%
temp = 12

# %%
if temp > 25:
    print("Warm")
else:
    print("Cold")
# Out:
# Warm

# %%
"warm" if temp > 25 else "cold"
# Out:
# 'cold'

# %%
list_of_25= [25 for i in range (1,31)]

# %%
len(list_of_25)
# Out:
# 30

# %%
list_of_25[5]
# Out:
# 25
