# %% [markdown]
# ## Dictionary

# %% [markdown]
# #### Dictionary is a python data structure that store's the data in {key : value} format

# %% [markdown]
# #### This ia a linear data structure

# %% [markdown]
# #### Keys must be unique

# %% [markdown]
# #### Other than string data structure, keys could be of any data type

# %% [markdown]
# #### Values could be of any data type

# %% [markdown]
# ## CH-1 dict literal

# %%
my_dict = dict()

# %%
print(type(my_dict))
# Out:
# <class 'dict'>

# %%
my_dict = {
    "key1" : 1,
    "key1" : 1,
    "key1" : 1,
    "key1" : 1,
}

# %%
len(my_dict)
# Out:
# 1

# %%
my_dict = {
    "key1" : 1,
    "key2" : 1,
    "key3" : 1,
    "key4" : 1,
} # string keys are allowed

# %%
len(my_dict)
# Out:
# 4

# %%
num_dict = {1:1, 2:1, 3:1} # int, float, bool keys are allowed

# %%
num_dict
# Out:
# {1: 1, 2: 1, 3: 1}

# %%
complex_dict = {
    23+4j : 23
}

# %%
complex_dict # complex keys are also allowed
# Out:
# {(23+4j): 23}

# %%
# int, bool, float, complex, string as wel as None works/

# %%
none_dict = {
    None : 23,
    1 : 1,
    2.4 : 1,
    True : 1,
    34+7j : 1,
    "Human" : 1
}

# %%
none_dict
# Out:
# {None: 23, 1: 1, 2.4: 1, (34+7j): 1, 'Human': 1}

# %% [markdown]
# #### what does not work

# %%
list_dict = {
    [1,2,3] : 1
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 list_dict = {
#       2     [1,2,3] : 1
#       3 }
#
# TypeError: unhashable type: 'list'

# %%
set_dict = {
    {1,2,3} : 1
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 set_dict = {
#       2     {1,2,3} : 1
#       3 }
#
# TypeError: unhashable type: 'set'

# %%
tuple_dict = {
    (1,2,3): 1
}

# %%
tuple_dict
# Out:
# {(1, 2, 3): 1}

# %% [markdown]
# ## Values

# %%
my_dict = {
    'class1' : ['subham','tanishq','caren'],
    'class2' : ['milan','ayushman','varsha']
}

# %%
my_dict
# Out:
# {'class1': ['subham', 'tanishq', 'caren'],
#  'class2': ['milan', 'ayushman', 'varsha']}

# %% [markdown]
# ## Indexing

# %%
my_dict['class1']
# Out:
# ['subham', 'tanishq', 'caren']

# %% [markdown]
# ### Add new items using indexing

# %%
my_dict['class3'] = ['amol','chirag','rohini']

# %%
my_dict
# Out:
# {'class1': ['subham', 'tanishq', 'caren'],
#  'class2': ['milan', 'ayushman', 'varsha'],
#  'class3': ['amol', 'chirag', 'rohini']}

# %% [markdown]
# ### Update an item using indexing

# %%
my_dict['class3'] = 'banana'

# %%
my_dict
# Out:
# {'class1': ['subham', 'tanishq', 'caren'],
#  'class2': ['milan', 'ayushman', 'varsha'],
#  'class3': 'banana'}

# %% [markdown]
# ### delete using indexing

# %%
del my_dict['class3']

# %%
my_dict
# Out:
# {'class1': ['subham', 'tanishq', 'caren'],
#  'class2': ['milan', 'ayushman', 'varsha']}

# %% [markdown]
# ## CH-3 Looping

# %%
my_dict
# Out:
# {'class1': ['subham', 'tanishq', 'caren'],
#  'class2': ['milan', 'ayushman', 'varsha']}

# %%
for i in my_dict:
    print(i)
# Out:
# class1
# class2

# %% [markdown]
# ### Structure of a dictionary

# %%
# item - {key:value}

# %%
# key - {key}

# %%
# value - {value}

# %%
my_dict.items()
# Out:
# dict_items([('class1', ['subham', 'tanishq', 'caren']), ('class2', ['milan', 'ayushman', 'varsha'])])

# %%
# list of tuples where each tuple has two items at least, ie key & value

# %%
my_dict.keys()
# Out:
# dict_keys(['class1', 'class2'])

# %%
my_dict.values()
# Out:
# dict_values([['subham', 'tanishq', 'caren'], ['milan', 'ayushman', 'varsha']])

# %%
for i in dir(dict):
    if i[0] != "_":
        print(i)
    else:
        pass
# Out:
# clear
# copy
# fromkeys
# get
# items
# keys
# pop
# popitem
# setdefault
# update
# values

# %%
my_dict.pop('class1')
# Out:
# ['subham', 'tanishq', 'caren']

# %%
my_dict
# Out:
# {'class2': ['milan', 'ayushman', 'varsha']}

# %%
my_dict['class1'] = ['milan', 'ayushman', 'varsha']

# %%
my_dict
# Out:
# {'class2': ['milan', 'ayushman', 'varsha'],
#  'class1': ['milan', 'ayushman', 'varsha']}

# %%
my_dict.popitem()
# Out:
# ('class1', ['milan', 'ayushman', 'varsha'])

# %%
my_dict
# Out:
# {'class2': ['milan', 'ayushman', 'varsha']}

# %%
my_dict.update({'class1' : ['milan', 'ayushman', 'varsha']})

# %%
my_dict
# Out:
# {'class2': ['milan', 'ayushman', 'varsha'],
#  'class1': ['milan', 'ayushman', 'varsha']}

# %%
my_dict
# Out:
# {'class2': ['milan', 'ayushman', 'varsha'],
#  'class1': ['milan', 'ayushman', 'varsha']}

# %% [markdown]
# ### update the key name (not possible)

# %% [markdown]
# #### take the old key
# #### store the value
# #### delete the key
# #### create new key with the desired name
# #### assign the stored value

# %%
my_dict
# Out:
# {'class2': ['milan', 'ayushman', 'varsha'],
#  'class1': ['milan', 'ayushman', 'varsha']}

# %%
my_value = my_dict['class1']

# %%
my_value
# Out:
# ['milan', 'ayushman', 'varsha']

# %%
del my_dict['class1']

# %%
my_dict
# Out:
# {'class2': ['milan', 'ayushman', 'varsha']}

# %%
my_dict['class3'] = my_value

# %%
my_dict
# Out:
# {'class2': ['milan', 'ayushman', 'varsha'],
#  'class3': ['milan', 'ayushman', 'varsha']}

# %%
my_dict.get('class3') # returns the value of the key
# Out:
# ['milan', 'ayushman', 'varsha']

# %%
my_dict.fromkeys(['class2','class3'])
# Out:
# {'class2': None, 'class3': None}

# %% [markdown]
# # Set data structure

# %%
my_set = set()

# %%
print(type(my_set))
# Out:
# <class 'set'>

# %%
my_set = {1,2,3}

# %%
# set is mutable

# %%
# does not allow : duplicates

# %%
# not ordered

# %%
my_set
# Out:
# {1, 2, 3}

# %% [markdown]
# ### set ops

# %%
set_a = {1,2,3,4,5}

# %%
set_b = {4,5,6,7,8}

# %%
set_c = {9,10}

# %%
for i in dir(set):
    if i[0] != "_":
        print(i)
    else:
        pass
# Out:
# add
# clear
# copy
# difference
# difference_update
# discard
# intersection
# intersection_update
# isdisjoint
# issubset
# issuperset
# pop
# remove
# symmetric_difference
# symmetric_difference_update
# union
# update

# %%
set_c.add(11) # adds an item in a random place

# %%
set_c
# Out:
# {9, 10, 11}

# %%
set_c.remove(11) # revomes an item of choice

# %%
set_c
# Out:
# {9, 10}

# %%
set_c.pop() # pops out a random item
# Out:
# 9

# %%
set_c.clear()

# %%
set_c
# Out:
# set()

# %%
# difference
# intersection
# union
# issubset
# issuperset
# isdisjoint

# %%
set_a.difference(set_b)
# Out:
# {1, 2, 3}

# %%
set_b.difference(set_a)
# Out:
# {6, 7, 8}

# %%
set_a.intersection(set_b)
# Out:
# {4, 5}

# %%
set_b.intersection(set_a)
# Out:
# {4, 5}

# %%
set_a.union(set_b)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
set_d = {1,2,3}

# %%
set_d.issubset(set_a)
# Out:
# True

# %%
set_a.issuperset(set_d)
# Out:
# True

# %%
set_a.isdisjoint(set_c)
# Out:
# True
