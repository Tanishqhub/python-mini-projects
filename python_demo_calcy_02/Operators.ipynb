# %% [markdown]
# # Operators

# %% [markdown]
# ### 1. Arithmetic operators

# %% [markdown]
# > #### +
# > #### -
# > #### /
# > #### *
# > #### //
# > #### %
# > #### **

# %%
print(1+3) # addition
# Out:
# 4

# %%
# substraction
print(10-3)
# Out:
# 7

# %%
print(21 * 2.2)
# Out:
# 46.2

# %%
print(10/3)
# Out:
# 3.3333333333333335

# %%
print(10/5)
# Out:
# 2.0

# %%
print(10//5)
# Out:
# 2

# %%
print(10//3)
# Out:
# 3

# %%
print(10%2)
# Out:
# 0

# %%
print(10%3)
# Out:
# 1

# %%
print(2**3) # power 3
# Out:
# 8

# %%
print(3**2) # power 2
# Out:
# 9

# %%
print(1 + True) # 1 + 1
# Out:
# 2

# %%
print(True) # True
# Out:
# True

# %%
print(False) # False
# Out:
# False

# %%
print(False + True) # 0 + 1
# Out:
# 1

# %%
print(5 + False) # 5 + 0
# Out:
# 5

# %%
print(True / 5)
# Out:
# 0.2

# %% [markdown]
# ### 2. Assignment operation

# %%
num1 = 5

# %%
num2 = 10

# %%
num1 = num2

# %%
print(num1)
# Out:
# 10

# %%
print(num2)
# Out:
# 10

# %%
num1 = num1 + 5

# %%
print(num1)
# Out:
# 15

# %%
x = y = z = 10

# %%
x
# Out:
# 10

# %%
y
# Out:
# 10

# %%
z
# Out:
# 10

# %%
a, b, c = 1, a + 2, b + 3

# %%
a
# Out:
# 1

# %%
b
# Out:
# 3

# %%
c
# Out:
# 6

# %%
a, b, c = 1, a + 2, b + 3

# %% [markdown]
# ### 3. Comparision operators

# %%
n1 = 2
n2 = 3

# %%
print(n1 == n2)
# Out:
# False

# %%
n2 = n1 # here

# %%
print(n1 == n2)
# Out:
# True

# %%
print(n1 > n2)
# Out:
# False

# %%
print(n1 < n2)
# Out:
# True

# %%
print(n1 > n2)
# Out:
# False

# %%
print(n1 >= n2)
# Out:
# True

# %% [markdown]
# ## 4. Logical operators

# %%
temp1 = 22
temp2 = 33

# %%
print((temp1 > temp2) and (temp1 == temp2))
# Out:
# False

# %%
print((temp2 > temp1) and (temp1 == temp1))
# Out:
# True

# %%
print((temp2 > temp1) or (temp1 == temp2))
# Out:
# True

# %%
print(not (temp2 > temp1))
# Out:
# False

# %%
print((temp2 > temp1) or (temp1 != temp2))
# Out:
# True

# %%
print((temp1 > temp2) or (temp1 == temp2))
# Out:
# False

# %% [markdown]
# ## 5. Identity

# %%
x = 5
y = 5

# %%
x is y
# Out:
# True

# %%
x is not y
# Out:
# False

# %% [markdown]
# ## 6. Membership

# %%
print('t' in 'tanishq')
# Out:
# True

# %%
print('z' not in 'tanishq')
# Out:
# True

# %%
print('s' not in 'tanishq')
# Out:
# False

# %%
x == y
# Out:
# True

# %%
x is y
# Out:
# True

# %% [markdown]
# # Control flow

# %%
# if - else

# %%
temperature = 30

# %%
if temperature > 22 and temperature < 28:
    print('Its a good weather')
else:
    print('Go home and sleep')
# Out:
# Go home and sleep

# %%
if 22 < temperature < 28:
    print('Its a good weather')
else:
    print('Go home and sleep')
# Out:
# Go home and sleep

# %%
22 < temperature
# Out:
# True

# %%
temperature < 28
# Out:
# False

# %%
tanishq = 'trainer'

# %%
if tanishq:
    print('hii')
# Out:
# hii
