# %% [raw]
# Variable assignment
# Fancy variable assignment
# All data types code syntax
# Print function and parameters
# Type function
# Type casting
# Input function
# Program - take two user input numbers and add them and show the output
# Arithmetic operators
# Assignment operators
# Comparison operators

# %%
x = 5

# %%
x
# Out:
# 6

# %%
x = 6

# %%
x, y, z = 1,2,3

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
3 + "tanishq"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 3 + "tanishq"
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print(x
# Out:
#   Cell In[13], line 1
#     print(x
#            ^
# SyntaxError: incomplete input

# %%
# error 1 : NameError
# error 2 : SyntaxError: incomplete input
# error 3 : TypeError

# %%
# singular: int, float, bool, complex, None

# %% [markdown]
# ## Type function

# %%
print(type(4))
# Out:
# <class 'int'>

# %%
# int : 3 4

# %%
op = 2 + 3
print(op)
# Out:
# 5

# %%
op + 1
# Out:
# 6

# %%
print(type(4.5))
# Out:
# <class 'float'>

# %%
print(3 + True)
# Out:
# 4

# %%
tanishq = True

# %%
if tanishq:
    inp = input('Enter something')
    if inp == 'false':
        tanishq = False
# Out:
# Enter something false

# %%
tanishq
# Out:
# False

# %%
com = 4+3j

# %%
chirag = None

# %%
if chirag:
    print('present')
else:
    print('dead')
# Out:
# dead

# %%
com.imag
# Out:
# 3.0

# %%
type(chirag)
# Out:
# NoneType

# %%
# collections

# %%
nums = [1,2,3,4,5]

# %%
type(nums)
# Out:
# dict

# %%
nums
# Out:
# {1: 'a', 2: 'b', 3: 'c', 4: 'd'}

# %% [markdown]
# ## Type Casting

# %%
num1 = 1

# %%
type(num1)
# Out:
# int

# %%
num1 = float(num1)

# %%
num1
# Out:
# 1.0

# %%
num2 = 4.5

# %%
type(num2)
# Out:
# float

# %%
num2 = int(num2)

# %%
num2
# Out:
# 4

# %%
n1 = 5
n2 = 3

# %%
n1 = n1/n2 # implicit

# %%
type(n1)
# Out:
# float

# %%
n1 = int(input('Enter number 1: '))
n2 = int(input('Enter number 2: '))
# Out:
# Enter number 1:  1
# Enter number 2:  2

# %%
n1 + n2
# Out:
# 3

# %%
input('Enter something: ')
# Out:
# Enter something:  hii
# 'hii'

# %%
print(100 * '-')
print('Welcome to dumb calcy')
print(100 * '-')
n1 = int(input('Enter number 1: '))
n2 = int(input('Enter number 2: '))
op = n1 + n2
print()
print('Your output is',op)
# Out:
# ----------------------------------------------------------------------------------------------------
# Welcome to dumb calcy
# ----------------------------------------------------------------------------------------------------
# Enter number 1:  4
# Enter number 2:  67
# Your output is 71

# %%
print('tanishq',x)
# Out:
# tanishq 1

# %% [markdown]
# # Operators

# %% [markdown]
# ### Arithmetic operators

# %%
num = input("Enter number:")
num = int(num)
print(num)
name1 = input("Enter name: ")
print(name1)

# Printing type of input value
print ("type of number", type(num))
print ("type of name", type(name1))  # sir pls examplane this example
# Out:
# Enter number: 2
# 2
# Enter name:  python
# python
# type of number <class 'int'>
# type of name <class 'str'>

# %% [markdown]
# # Big

# %% [markdown]
# ## small

# %% [markdown]
# ### very small

# %%
print(100 * '-')
print('welcome to dumb calcy')
print(100 * '-')
n1 = int(input('Enter number 1:'))
n2 = int(input('Enter number 2:'))
op = n1 + n2
print()
print('Your output is' ,  op)
# Out:
# ----------------------------------------------------------------------------------------------------
# welcome to dumb calcy
# ----------------------------------------------------------------------------------------------------
# Enter number 1: 2
# Enter number 2: 5
# Your output is 7

# %% [markdown]
# ### Arithmetic

# %%
print(1 + 3) # + addition
# Out:
# 4

# %%
print(5 - 3) # - subtraction
# Out:
# 2

# %%
print(3 * 2) # * multiplication
# Out:
# 6

# %%
print(10 / 2) # / division
# Out:
# 5.0

# %%
print(10 // 2) # // floor division (root value)
# Out:
# 5

# %%
print(3 ** 2) # ** exponential
# Out:
# 9

# %%
print(10 % 2) # % modulo
# Out:
# 0

# %% [markdown]
# ### Assignment Operator

# %%
name = 'tanishq' # = assignment operator

# %%
num = 3

# %%
num = num + 2

# %%
num += 1

# %%
num -= 1 # works the same way with all arithmetic operatos

# %% [markdown]
# ### Comparision Operators

# %%
name == 'tanishq'
# Out:
# True

# %%
name == 'caren'
# Out:
# False

# %%
weather = 50

# %%
weather > 30
# Out:
# True

# %%
weather < 20
# Out:
# False

# %%
weather > 50
# Out:
# False

# %%
weather >= 50
# Out:
# True

# %%
weather == 50
# Out:
# True

# %%
weather != 50
# Out:
# False

# %% [markdown]
# ### Logical

# %%
weather != 50 and weather < 30
# Out:
# False

# %%
weather == 50 and weather < 30
# Out:
# False

# %%
weather == 50 and weather > 30
# Out:
# True

# %%
weather == 50 or weather < 30
# Out:
# True

# %%
not weather != 50
# Out:
# True

# %%
not weather == 50
# Out:
# False

# %% [markdown]
# ### Identity

# %%
name is new
# Out:
# True

# %%
new = 'tanishq'

# %%
weather is weather>30
# Out:
# True

# %%
weather is weather < 30
# Out:
# False

# %%
weather is not weather < 30
# Out:
# False

# %%
x = 5
y = 6

# %%
x is not  y
# Out:
# True

# %% [markdown]
# ### Membership

# %%
nums
# Out:
# [1, 2, 3, 4, 5]

# %%
nums + [1]
# Out:
# [1, 2, 3, 4, 5, 1]

# %%
3 in nums
# Out:
# True

# %%
7 not in nums
# Out:
# True

# %%
(7 not in nums) + 5
# Out:
# 6

# %%
4 not in nums
# Out:
# False

# %%
'tanishq' in nums
# Out:
# False

# %%
nums
# Out:
# [1, 2, 3, 4, 5]

# %%
# Variable assignment 
# Fancy variable assignment 
# All data types code syntax 
# Print function and parameters
# Type function
# Type casting 
# Input function
# Program - take two user input numbers and add them and show the output
# Arithmetic operators
# Assignment operators
# Comparison operators
# Variable assignment 
# Fancy variable assignment 
# All data types code syntax 
# Print function and parameters
# Type function
# Type casting 
# Input function
# Program - take two user input numbers and add them and show the output
# Arithmetic operators
# Assignment operators
# Comparison operators

# %% [markdown]
# # Logic building

# %% [markdown]
# ### conditional statements

# %%
# to check a condition, control flow statements are used

# %%
valid_users = ['tanishq', 'chirag', 'caren', 'roshni', 'priya','ashrafun']

# %%
valid_users
# Out:
# ['tanishq', 'chirag', 'caren', 'roshni', 'priya', 'ashrafun']

# %%
user = input('Enter you name: ')
if user.lower() in valid_users:
    num1 = input('Enter num1: ')
    num2 = input('Enter num2: ')
    if num1.isdigit and num2.isdigit:
        num1 = int(num1)
        num2 = int(num2)

        op = num1 + num2

        print(op)
    else:
        num1 = input('Renter num1: ')
        num2 = input('Renter num2: ')
else:
    user = input('Renter you name: ')
# Out:
# Enter you name:  caren
# Enter num1:  6
# Enter num2:  banana
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[191], line 7
#       5 if num1.isdigit and num2.isdigit:
#       6     num1 = int(num1)
# ----> 7     num2 = int(num2)
#       9     op = num1 + num2
#      11     print(op)
#
# ValueError: invalid literal for int() with base 10: 'banana'

# %%
name.upper()
# Out:
# 'TANISHQ'

# %%
number = 'abc'

# %%
type(number)
# Out:
# str

# %%
number.isalpha()
# Out:
# True

# %%
number.isdigit()
# Out:
# False
